# %%
while choice != '4':
    choice = show_menu()
    if choice == '1':data = []
choice = 'random'
def line():
    print('---------------------------')

def show_menu():
    line()
    print('MENU')
    line()
    print('1. Add Course')
    print('2. Course Added')
    print('3. View Course list')
    print('4. Exit')
    line()
    choice = input('Enter your choice: ')
    return choice

        item = input('What course should be enrolled ')
        data.append(item)
        print('Course', item, 'added')
    elif choice == '2':
        item = input('Which course you want to unenroll ')
        if item in data:
            data.remove(item)
            print('Course Unenrolled', item)
        else:
            print('Could not find this course', item)
    elif choice == '3':
        print('Your enrolled course list:')
        for item in data:
            print(item)
    elif choice == '4':
        print('Goodbye!')
    else:
        print('Please enter one of 1, 2, 3 or 4')
# Out:
# ---------------------------
# MENU
# ---------------------------
# 1. Add Course
# 2. Course Added
# 3. View Course list
# 4. Exit
# ---------------------------
# Enter your choice: 3
# List of to-do items:
# ---------------------------
# MENU
# ---------------------------
# 1. Add Course
# 2. Course Added
# 3. View Course list
# 4. Exit
# ---------------------------
# Enter your choice: 1
# What course should be enrolled CSE412
# Course CSE412 added
# ---------------------------
# MENU
# ---------------------------
# 1. Add Course
# 2. Course Added
# 3. View Course list
# 4. Exit
# ---------------------------
# Enter your choice: 1
# What course should be enrolled CSE413
# Course CSE413 added
# ---------------------------
# MENU
# ---------------------------
# 1. Add Course
# 2. Course Added
# 3. View Course list
# 4. Exit
# ---------------------------
# Enter your choice: 1
# What course should be enrolled CSE414
# Course CSE414 added
# ---------------------------
# MENU
# ---------------------------
# 1. Add Course
# 2. Course Added
# 3. View Course list
# 4. Exit
# ---------------------------
# Enter your choice: 3
# List of to-do items:
# CSE412
# CSE413
# CSE414
# ---------------------------
# MENU
# ---------------------------
# 1. Add Course
# 2. Course Added
# 3. View Course list
# 4. Exit
# ---------------------------
# Enter your choice: 2
# What is to be marked as done? CSE413
# Removed item CSE413
# ---------------------------
# MENU
# ---------------------------
# 1. Add Course
# 2. Course Added
# 3. View Course list
# 4. Exit
# ---------------------------
# Enter your choice: 3
# List of to-do items:
# CSE412
# CSE414
# ---------------------------
# MENU
# ---------------------------
# 1. Add Course
# 2. Course Added
# 3. View Course list
# 4. Exit
# ---------------------------
